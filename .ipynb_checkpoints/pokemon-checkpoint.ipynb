# %% [markdown]
# # Names: Austin He, Maya Lee, Kevin Barcenas Martinez, Luis Gamino

# %% [markdown]
# # Pokemon
#
# In this project we will be...

# %% [markdown]
# # Introduction
# What is the machine learning problem you are trying to solve?
# Why does the problem matter?
# What could the results of your predcitive matter be used for?
# Why would we want to be able to predict the thing you're trying to predict?
# Describe dataset:
#
# The pokedex.csv file consists of:
#
# images: Path to an image of the Pokemon, in the 'images' folder
#
# index: Each Pokemon number in the PokeDex.
#
# Name: Name of the Pokemon.
#
# Type 1: First type af the Pokemon.
#
# Type 2: Second type of the Pokemon. Not all have two types. This will be null in that case.
#
# Total: Sum of all stats.
#
# HP: Hit points, or health. How much damage a pokemon can withstand
#
# Attack: The base for normal attacks.
#
# Defense: The base resistance against normal attacks.
#
# SP. Atk.: The base for special attacks.
#
# SP. Def.: The base resistance against special attacks.
#
# Speed: Determines which Pokemon attacks first each round.

# %%
# Standard Headers
# You may add additional headers here if needed
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from pandas import DataFrame
import numpy as np
# Pokebase is a Pokemon API that has extensive information about each pokemon
# https://pokeapi.co/docs/v2
#import pokebase as pb

# Enable inline mode for matplotlib so that Jupyter displays graphs
# %matplotlib inline

# print your pandas version
pd.__version__
# Out:
# '2.2.2'

# %%
path = r"C:\Users\luisg\OneDrive\Desktop\CS 363M\Project1\Pokemon_ML\height_weight.csv"
data = pd.read_csv(path, skipinitialspace=True)
#data = pd.read_csv(r"C:\Users\Kevin\Downloads\Pokemon_ML\pokedex.csv", skipinitialspace=True)
display(data.head())
# Out:
#           Image  Index                    Name Type 1  Type 2  Total  HP  \
# 0  images/1.png      1               Bulbasaur  Grass  Poison    318  45
# 1  images/2.png      2                 Ivysaur  Grass  Poison    405  60
# 2  images/3.png      3                Venusaur  Grass  Poison    525  80
# 3  images/4.png      3  Venusaur Mega Venusaur  Grass  Poison    625  80
# 4  images/5.png      4              Charmander   Fire     NaN    309  39
#
#    Attack  Defense  SP. Atk.  SP. Def  Speed  Height  Weight
# 0      49       49        65       65     45     7.0    69.0
# 1      62       63        80       80     60    10.0   130.0
# 2      82       83       100      100     80    20.0  1000.0
# 3     100      123       122      120     80     NaN     NaN
# 4      52       43        60       50     65     6.0    85.0

# %% [markdown]
# # Part 1: Data cleaning, data exploration, feature engineering, etc.

# %% [markdown]
# Merging 'Type 1' and 'Type 2' Columns into one column called 'Type'

# %%
data.fillna({"Type 2":""}, inplace=True)
types = data['Type 1'] + " " + data['Type 2']
#inserting merged columns into the data set
data.insert(5, "Types", types)
display(data.head())
# Out:
#           Image  Index                    Name Type 1  Type 2         Types  \
# 0  images/1.png      1               Bulbasaur  Grass  Poison  Grass Poison
# 1  images/2.png      2                 Ivysaur  Grass  Poison  Grass Poison
# 2  images/3.png      3                Venusaur  Grass  Poison  Grass Poison
# 3  images/4.png      3  Venusaur Mega Venusaur  Grass  Poison  Grass Poison
# 4  images/5.png      4              Charmander   Fire                 Fire
#
#    Total  HP  Attack  Defense  SP. Atk.  SP. Def  Speed  Height  Weight
# 0    318  45      49       49        65       65     45     7.0    69.0
# 1    405  60      62       63        80       80     60    10.0   130.0
# 2    525  80      82       83       100      100     80    20.0  1000.0
# 3    625  80     100      123       122      120     80     NaN     NaN
# 4    309  39      52       43        60       50     65     6.0    85.0

# %%
# Adding weight and height in the data. This information is coming from the PokeAPI 
# Due to time consuming script to obtain the height and weight of the pokemons the
# data extraction was done locally and will be added as a csv file. 
# The script will be below

# data['Height'] = np.nan
# data['Weight'] = np.nan

# for index, row in df.iterrows():
#     pokemon_name = row['Name'].lower()
#     try:
#         current_pokemon = pb.pokemon(pokemon_name)
#         df.at[index, 'Height'] = current_pokemon.height
#         df.at[index, 'Weight'] = current_pokemon.weight
#     except Exception as e:
#         df.at[index, 'Height'] = np.nan
#         df.at[index, 'Weight'] = np.nan
# df.to_csv("pokemon_csv_with_heightweight.csv", index=False)

# %%
#Checking for NaNs
nan_data = data[data.isnull().any(axis=1)]
display(nan_data)
# Data Cleaning: Remove Image column and Index column

data.drop("Image", axis=1, inplace=True) # Drop image column, not necessary for models
data.drop("Index", axis=1, inplace=True) # Drop the Index column, inputting ordered information could mess up the model
data.drop("Type 1", axis=1, inplace=True)
data.drop("Type 2", axis=1, inplace=True)
data.drop("Name", axis=1, inplace=True)
# data.drop("Total", axis=1, inplace =True) Uncomment for later since its a total of all the other columns
data.dropna(inplace=True) # dropping pokemons without height and weight
display(data.head())


#Separating Labels and Features
class_labels = data['Types']
features = data.copy(deep=True)
features.drop('Types', axis=1, inplace=True) #
display(features.head())
display(class_labels)
# Out:
#                 Image  Index                        Name  Type 1   Type 2  \
# 3        images/4.png      3      Venusaur Mega Venusaur   Grass   Poison
# 7        images/8.png      6  Charizard Mega Charizard X    Fire   Dragon
# 8        images/9.png      6  Charizard Mega Charizard Y    Fire   Flying
# 12      images/13.png      9    Blastoise Mega Blastoise   Water
# 19      images/20.png     15      Beedrill Mega Beedrill     Bug   Poison
# ...               ...    ...                         ...     ...      ...
# 1209  images/1210.png   1022                Iron Boulder    Rock  Psychic
# 1210  images/1211.png   1023                  Iron Crown   Steel  Psychic
# 1211  images/1212.png   1024       Terapagos Normal Form  Normal
# 1212  images/1213.png   1024     Terapagos Terastal Form  Normal
# 1213  images/1214.png   1024      Terapagos Stellar Form  Normal
#
#               Types  Total   HP  Attack  Defense  SP. Atk.  SP. Def  Speed  \
# 3      Grass Poison    625   80     100      123       122      120     80
# 7       Fire Dragon    634   78     130      111       130       85    100
# 8       Fire Flying    634   78     104       78       159      115    100
# 12           Water     630   79     103      120       135      115     78
# 19       Bug Poison    495   65     150       40        15       80    145
# ...             ...    ...  ...     ...      ...       ...      ...    ...
# 1209   Rock Psychic    590   90     120       80        68      108    124
# 1210  Steel Psychic    590   90      72      100       122      108     98
# 1211        Normal     450   90      65       85        65       85     60
# 1212        Normal     600   95      95      110       105      110     85
# 1213        Normal     700  160     105      110       130      110     85
#
#       Height  Weight
# 3        NaN     NaN
# 7        NaN     NaN
# 8        NaN     NaN
# 12       NaN     NaN
# 19       NaN     NaN
# ...      ...     ...
# 1209     NaN     NaN
# 1210     NaN     NaN
# 1211     NaN     NaN
# 1212     NaN     NaN
# 1213     NaN     NaN
#
# [264 rows x 15 columns]
#           Types  Total  HP  Attack  Defense  SP. Atk.  SP. Def  Speed  Height  \
# 0  Grass Poison    318  45      49       49        65       65     45     7.0
# 1  Grass Poison    405  60      62       63        80       80     60    10.0
# 2  Grass Poison    525  80      82       83       100      100     80    20.0
# 4         Fire     309  39      52       43        60       50     65     6.0
# 5         Fire     405  58      64       58        80       65     80    11.0
#
#    Weight
# 0    69.0
# 1   130.0
# 2  1000.0
# 4    85.0
# 5   190.0
#    Total  HP  Attack  Defense  SP. Atk.  SP. Def  Speed  Height  Weight
# 0    318  45      49       49        65       65     45     7.0    69.0
# 1    405  60      62       63        80       80     60    10.0   130.0
# 2    525  80      82       83       100      100     80    20.0  1000.0
# 4    309  39      52       43        60       50     65     6.0    85.0
# 5    405  58      64       58        80       65     80    11.0   190.0
# 0         Grass Poison
# 1         Grass Poison
# 2         Grass Poison
# 4                Fire
# 5                Fire
#              ...
# 1199    Poison Psychic
# 1200      Poison Fairy
# 1205      Steel Dragon
# 1206      Grass Dragon
# 1214      Poison Ghost
# Name: Types, Length: 951, dtype: object

# %% [markdown]
# Feature Exploring

# %%
#Frequency of different Types
types_frequency = class_labels.value_counts()
plt.bar(types_frequency.index, types_frequency.values, color='skyblue')
plt.xlabel('Types')
plt.ylabel('Frequency')
plt.title('Frequency of Types')
plt.show()
#Plot of the first 15 frequent type
first_fifteen = types_frequency[:15]
plt.figure(figsize=(12, 6))
plt.bar(first_fifteen.index, first_fifteen.values, color='skyblue')
plt.xlabel('Types')
plt.ylabel('Frequency')
plt.title('Frequency of First 15 Types')
plt.show()

# %%
#Printing the data of types statistics
types_data =  data.groupby('Types')
types_data.describe()
# Out:
#               Total                                                        \
#               count        mean         std    min     25%    50%     75%
# Types
# Bug            22.0  287.954545  106.073863  180.0  205.00  241.5  366.75
# Bug Dark        1.0  450.000000         NaN  450.0  450.00  450.0  450.00
# Bug Electric    4.0  422.750000   80.983023  319.0  379.75  436.0  479.00
# Bug Fairy       2.0  384.000000  113.137085  304.0  344.00  384.0  424.00
# Bug Fighting    3.0  546.666667   40.414519  500.0  535.00  570.0  570.00
# ...             ...         ...         ...    ...     ...    ...     ...
# Water Ice       4.0  510.000000   26.457513  475.0  497.50  515.0  527.50
# Water Poison    3.0  430.000000   90.415707  335.0  387.50  440.0  477.50
# Water Psychic   6.0  461.333333   73.434778  315.0  475.75  484.0  490.00
# Water Rock      5.0  446.000000   61.278055  355.0  410.00  485.0  485.00
# Water Steel     1.0  530.000000         NaN  530.0  530.00  530.0  530.00
#
#                         HP             ... Height       Weight               \
#                  max count       mean  ...    75%   max  count         mean
# Types                                  ...
# Bug            500.0  22.0  50.136364  ...   7.00  15.0   22.0   112.681818
# Bug Dark       450.0   1.0  71.000000  ...  10.00  10.0    1.0   175.000000
# Bug Electric   500.0   4.0  63.500000  ...   9.75  15.0    4.0   176.000000
# Bug Fairy      464.0   2.0  50.000000  ...   1.75   2.0    2.0     3.500000
# Bug Fighting   570.0   3.0  86.000000  ...  21.00  24.0    3.0  1375.333333
# ...              ...   ...        ...  ...    ...   ...    ...          ...
# Water Ice      535.0   4.0  90.000000  ...  21.25  25.0    4.0  1618.750000
# Water Poison   515.0   3.0  61.666667  ...  12.50  16.0    3.0   348.000000
# Water Psychic  520.0   6.0  83.000000  ...  19.00  25.0    6.0   638.333333
# Water Rock     495.0   5.0  76.600000  ...  10.00  12.0    5.0   482.800000
# Water Steel    530.0   1.0  84.000000  ...  17.00  17.0    1.0   845.000000
#
#
#                        std     min      25%     50%      75%     max
# Types
# Bug             121.525379    10.0    37.00    78.5   152.50   550.0
# Bug Dark               NaN   175.0   175.00   175.0   175.00   175.0
# Bug Electric    191.577660     6.0    80.25   124.0   219.75   450.0
# Bug Fairy         2.121320     2.0     2.75     3.5     4.25     5.0
# Bug Fighting   1704.167050   250.0   395.00   540.0  1938.00  3336.0
# ...                    ...     ...      ...     ...      ...     ...
# Water Ice       453.401496  1200.0  1293.75  1537.5  1862.50  2200.0
# Water Poison    271.784841    39.0   247.00   455.0   502.50   550.0
# Water Psychic   289.528352   190.0   466.25   790.0   798.75   900.0
# Water Rock      476.740705    50.0   165.00   234.0   810.00  1155.0
# Water Steel            NaN   845.0   845.00   845.0   845.00   845.0
#
# [190 rows x 72 columns]

# %%
# Printing the values of the mean of the features depending on the types
hp_by_types = types_data['HP']
hp_mean = hp_by_types.mean()
print(hp_mean.sort_values())
attack_by_types = types_data['Attack']
attack_mean = attack_by_types.mean()
print(attack_mean.sort_values())
defense_by_types = types_data['Defense']
defense_mean = defense_by_types.mean()
print(defense_mean.sort_values())
sp_attack_by_types = types_data['SP. Atk.']
sp_attack_mean = sp_attack_by_types.mean()
print(sp_attack_mean.sort_values())
sp_defense_by_types = types_data['SP. Def']
sp_defense_mean = sp_defense_by_types.mean()
print(sp_defense_mean.sort_values())
speed_by_types = types_data['Speed']
speed_mean = speed_by_types.mean()
print(speed_mean.sort_values())
height_by_types = types_data['Height']
height_mean = height_by_types.mean()
print(height_mean.sort_values())
weight_by_types = types_data['Weight']
weight_mean = weight_by_types.mean()
print(weight_mean.sort_values())
# Out:
# Types
# Bug Ghost             1.0
# Bug Ground           31.0
# Poison Bug           40.0
# Electric Poison      40.0
# Fighting Psychic     45.0
#                     ...
# Ghost Flying        120.0
# Ground Normal       130.0
# Psychic Ghost       137.0
# Psychic Steel       137.0
# Dark Ground         155.0
# Name: HP, Length: 190, dtype: float64
# Types
# Electric Poison     38.000000
# Ice Psychic         40.000000
# Normal Fairy        41.250000
# Ghost Fire          41.666667
# Bug Psychic         43.333333
#                       ...
# Fighting Dragon    135.000000
# Ground Steel       135.000000
# Psychic Steel      137.000000
# Ground Normal      140.000000
# Dragon Electric    150.000000
# Name: Attack, Length: 190, dtype: float64
# Types
# Ice Psychic         25.0
# Normal Fairy        30.0
# Electric Poison     35.0
# Ghost Flying        39.0
# Electric Normal     42.5
#                    ...
# Steel Rock         140.0
# Rock Fairy         150.0
# Poison Ghost       160.0
# Rock Steel         160.5
# Steel Ground       200.0
# Name: Defense, Length: 190, dtype: float64
# Types
# Poison Bug         30.000000
# Bug Ghost          30.000000
# Bug Ground         30.000000
# Rock               37.812500
# Flying             38.000000
#                      ...
# Poison Psychic    130.000000
# Steel Dragon      131.666667
# Normal Dragon     135.000000
# Psychic Ghost     137.000000
# Dragon Fire       150.000000
# Name: SP. Atk., Length: 190, dtype: float64
# Types
# Bug Ground          30.000000
# Bug Ghost           30.000000
# Normal Fairy        33.750000
# Electric Poison     35.000000
# Ground Rock         43.333333
#                       ...
# Rock Steel         119.250000
# Dragon Fire        120.000000
# Dragon Psychic     120.000000
# Poison Fairy       125.000000
# Rock Fairy         150.000000
# Name: SP. Def, Length: 190, dtype: float64
# Types
# Normal Fairy        25.00
# Ghost Ground        25.00
# Rock Steel          28.25
# Fire Rock           30.00
# Steel Ground        30.00
#                     ...
# Fighting Flying    118.00
# Fighting Poison    120.00
# Dragon Normal      121.00
# Dark Ice           125.00
# Fighting Dragon    135.00
# Name: Speed, Length: 190, dtype: float64
# Types
# Bug Fairy          1.500000
# Electric Fairy     2.000000
# Electric Ghost     3.000000
# Poison Ghost       3.000000
# Bug Psychic        3.666667
#                     ...
# Psychic Steel     34.000000
# Psychic Ghost     40.000000
# Steel Flying      54.500000
# Poison Dragon     84.666667
# Steel Ground      92.000000
# Name: Height, Length: 190, dtype: float64
# Types
# Electric Ghost       3.000000
# Poison Ghost         3.000000
# Bug Fairy            3.500000
# Bug Ghost           12.000000
# Electric Fairy      22.000000
#                      ...
# Poison Dragon     3938.333333
# Steel Ground      4000.000000
# Fire Steel        4300.000000
# Steel Flying      5252.000000
# Dark Ground       6997.000000
# Name: Weight, Length: 190, dtype: float64

# %%
# Seeing if there is a correlation between height and weight
plt.scatter(data['Height'], data['Weight'])
plt.xlabel('Height')
plt.ylabel('Weight')
plt.title("Height and Weight of Pokemon")
# Out:
# Text(0.5, 1.0, 'Height and Weight of Pokemon')

# %%
# Correlation between speed and weight
plt.scatter(data['Speed'], data['Weight'])
plt.xlabel('Speed')
plt.ylabel('Weight')
plt.title("Speed and Weight of Pokemon")
# Out:
# Text(0.5, 1.0, 'Speed and Weight of Pokemon')

# %%
# Correlation Matrix between numerical columns
import seaborn as sns
cor=features.corr()
plt.figure(figsize=(20,10), facecolor='w')
sns.heatmap(cor,xticklabels=cor.columns,yticklabels=cor.columns,annot=True)
plt.title("Correlation among all the Variables of the Dataset", size=20)
cor
# pd.plotting.scatter_matrix(data, figsize=(15,15))
# plt.show()
# Out:
#              Total        HP    Attack   Defense  SP. Atk.   SP. Def  \
# Total     1.000000  0.664513  0.712938  0.627116  0.704022  0.698191
# HP        0.664513  1.000000  0.464669  0.279880  0.372010  0.370872
# Attack    0.712938  0.464669  1.000000  0.467145  0.285847  0.227020
# Defense   0.627116  0.279880  0.467145  1.000000  0.211959  0.503716
# SP. Atk.  0.704022  0.372010  0.285847  0.211959  1.000000  0.489579
# SP. Def   0.698191  0.370872  0.227020  0.503716  0.489579  1.000000
# Speed     0.525149  0.161663  0.327310 -0.021961  0.405212  0.188513
# Height    0.503593  0.471640  0.381594  0.339254  0.321645  0.274614
# Weight    0.456669  0.458983  0.402660  0.443493  0.195750  0.268979
#
#              Speed    Height    Weight
# Total     0.525149  0.503593  0.456669
# HP        0.161663  0.471640  0.458983
# Attack    0.327310  0.381594  0.402660
# Defense  -0.021961  0.339254  0.443493
# SP. Atk.  0.405212  0.321645  0.195750
# SP. Def   0.188513  0.274614  0.268979
# Speed     1.000000  0.193530  0.025295
# Height    0.193530  1.000000  0.626095
# Weight    0.025295  0.626095  1.000000

# %% [markdown]
# # Part 2: Modeling
# Trying to predict what type a pokemon would be depending on their statistics.
# ### Classifers:
# - Linear/Logistic Regression
# - K nearest neighbors
# - Decision Trees
# - Random Forest
# - Support Vector Machine
# - Naive Bayes
# - Stacking

# %% [markdown]
# Normalize data
#
# Some evolutions should be scaled the same

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)
data = DataFrame(scaled_data)

# %%
#one hot encoding??
data = pd.get_dummies(data, columns=["Types"])

# %% [markdown]
# # Part 3: Results and analysis
